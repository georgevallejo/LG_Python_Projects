# %% [markdown]
# <a href="https://colab.research.google.com/github/georgevallejo/LG_Python_Projects/blob/main/ACE_Python_monday_8_1726.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class Review 08/17/2026
#
# ---

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/refs/heads/master/311_Service_Requests_from_2019May.csv')
# Out:
# /tmp/ipykernel_1227/2471651318.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/refs/heads/master/311_Service_Requests_from_2019May.csv')

# %%
df.count()

# %%
# df.dtypes
# df.info()
# df.count()
df['Closed Date'].isna().sum()
df['Created Date'].isna().sum()
print("original close date", df['Closed Date'].isna().sum())
print("original created date", df['Created Date'].isna().sum())
# temp = input('Hit Enter ')
# df['Closed Date'].count()
# df.shape[0] - df['Closed Date'].count()  # this is manual where .sum is already done
df['Closed Date'].head(20)   # NaN index 10

# df['Closed Date'] = pd.to_datetime(df['Closed Date'], errors='coerce')  # updating "Close Date" with cleaning data
df_cleaned_close_date =  pd.to_datetime(df['Closed Date'], errors='coerce')
df_cleaned_close_date.head(20)

# %%
# df.groupby([Borough])['Unique Key']
df_groupby = df.groupby(['Borough'])['Unique Key']

# %%
type(df_groupby)

# %%
df2_group_count = df.groupby(['Borough'])['Unique Key'].count()

# %%
type(df2)

# %%
df3_groupby_count_sort_values_ascending = df.groupby(['Borough'])['Unique Key'].count().sort_values(ascending=False)

# %%
type(df3_groupby_count_sort_values_ascending)

# %%
df4_group_count_sort_plot  = df.groupby(['Borough'])['Unique Key'].count().sort_values(ascending=False).plot(kind='bar')

# %%
type(df4_group_count_sort_plot)

# %% [markdown]
# **NYC 311 Service Request Analysys Report**

# %%
# print(df.dtypes)  # compare and contrast
# print(df.info())  # compare and contrast
# print(df.describe())    # compare and contrast

print("df.shape",df.shape)
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

print("\nAnalysis:")
print(f"The dataset contains {df.shape[0]} rows and {df.shape[1]} columns. "
      "Each row represents a 311 service request submitted during May 2019.")
# Out:
# df.shape (69637, 21)
# Rows: 69637
# Columns: 21
#
# Analysis:
# The dataset contains 69637 rows and 21 columns. Each row represents a 311 service request submitted during May 2019.

# %% [markdown]
# **Time Range Covered by the Dataset.  Validate if there is timing errors with negative values**

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])
# Valid dates → converted Invalid dates → become NaT Column dtype → becomes datetime64[ns]  count NaT values df['Closed Date'].isna().sum()

print("Earliest Date :", df['Created Date'].min())
print("Latest Date   :", df['Created Date'].max())

print("\nAnalysis:")
print(f"The dataset covers service from {df['Created Date'].min()} through {df['Created Date'].max()} for "
      "the 311 service request submitted during May 2019.")
# Out:
# Earliest Date : 2019-05-01 00:00:00
# Latest Date   : 2019-05-10 00:00:00
#
# Analysis:
# The dataset covers service from 2019-05-01 00:00:00 through 2019-05-10 00:00:00 for the 311 service request submitted during May 2019.
